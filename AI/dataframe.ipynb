# %%
import pandas as pd

# stock.xlsx 구조 기반 new_data 생성
columns = [
    "company_name", "debt_ratio", "equity_ratio", "debt_dependency_ratio",
    "current_ratio", "quick_ratio", "interest_coverage_ratio", "ebitda_to_total_debt",
    "cfo_to_total_debt", "free_cash_flow", "roe", "net_profit_margin",
    "total_asset_turnover", "accounts_receivable_turnover", "inventory_turnover",
    "sales_growth_rate", "operating_income_growth_rate", "total_asset_growth_rate",
    "news_sentiment"
]

new_data = pd.DataFrame([
    ["LG전자", "140.23%", "40.11%", "10.50%", "120.50%", "95.00%", 4.1, 0.12, 0.25, 1.2e11, "8.50%", "6.25%", 0.58, 8.9, 7.5, "5.4%", "6.7%", "8.2%", 45.12],
    ["SK하이닉스", "210.45%", "32.35%", "22.18%", "110.40%", "88.20%", 3.3, 0.15, 0.28, 2.8e11, "12.80%", "8.12%", 0.64, 9.7, 6.8, "6.5%", "8.9%", "10.1%", 47.90],
    ["네이버", "125.10%", "47.40%", "5.23%", "135.20%", "115.10%", 5.6, 0.20, 0.33, 9.3e10, "9.75%", "7.20%", 0.55, 10.5, 8.2, "8.3%", "7.4%", "6.9%", 50.21],
    ["하나은행", "98.25%", "51.55%", "7.40%", "140.00%", "130.00%", 8.2, 0.25, 0.37, 7.6e10, "10.10%", "9.50%", 0.62, 11.1, 9.7, "4.5%", "5.2%", "6.3%", 43.77],
    ["두산중공업", "230.00%", "25.30%", "27.00%", "80.00%", "70.00%", 1.5, 0.10, 0.20, 5.4e10, "5.80%", "3.25%", 0.45, 7.8, 5.9, "-2.5%", "-3.8%", "4.2%", 38.95],
], columns=columns)

# 엑셀로 저장
new_data.to_excel("new_data.xlsx", index=False)
print("✅ new_data.xlsx (현재 폴더)에 저장 완료")
# Out:
# ✅ new_data.xlsx (현재 폴더)에 저장 완료
